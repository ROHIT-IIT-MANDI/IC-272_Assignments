# %% [markdown]
# # PCA

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Iris.csv')

# %% [markdown]
# ### Getting Matrix And True Labels

# %%
original_data = np.array([df.iloc[:,0],df.iloc[:,1],df.iloc[:,2],df.iloc[:,3]])
X = np.array([df.iloc[:,0],df.iloc[:,1],df.iloc[:,2],df.iloc[:,3]])
means_X = np.array([(df.iloc[:,i].mean()) for i in range(4)])

# %%
flower = np.array(df.iloc[:,4])
#flower

# %%
def Corrected_outliers(X_):
    for i in range(4):
        Q1 = np.percentile(X_[i],25)
        Q2 = np.percentile(X_[i],50)
        Q3 = np.percentile(X_[i],75)
        lower = Q1 - 1.5*(Q3-Q1)
        upper = Q3 + 1.5*(Q3-Q1)

        for j in range(len(X_[i])):
            if X_[i][j]<lower or X_[i][j]>upper: X_[i][j] = Q2 

        return X_

X = Corrected_outliers(X) 
original_data = Corrected_outliers(original_data)

# %%
def sub_means(X_):
    for i in range(len(X_)):
        X_[i] = X_[i] - np.mean(X_[i])
    return X_

X = sub_means(X)

# %%
cov_matrix = np.dot(X,X.T)/150
cov_matrix 
# divided by no. of terms
# Out:
# array([[ 0.68112222, -0.03900667,  1.26519111,  0.51345778],
#        [-0.03900667,  0.18675067, -0.319568  , -0.11719467],
#        [ 1.26519111, -0.319568  ,  3.09242489,  1.28774489],
#        [ 0.51345778, -0.11719467,  1.28774489,  0.57853156]])

# %%
#Just checking if my matrix is correct :)
np.cov([X[0],X[1],X[2],X[3]])
# Out:
# array([[ 0.68569351, -0.03926846,  1.27368233,  0.5169038 ],
#        [-0.03926846,  0.18800403, -0.32171275, -0.11798121],
#        [ 1.27368233, -0.32171275,  3.11317942,  1.29638747],
#        [ 0.5169038 , -0.11798121,  1.29638747,  0.58241432]])

# %%
eigen_vals,eigenvec = np.linalg.eig(cov_matrix)

# %%
eigen_vals
# Out:
# array([4.19667516, 0.24062861, 0.07800042, 0.02352514])

# %%
real_eig = eigenvec.T
real_eig
# Out:
# array([[ 0.36158968, -0.08226889,  0.85657211,  0.35884393],
#        [-0.65653988, -0.72971237,  0.1757674 ,  0.07470647],
#        [-0.58099728,  0.59641809,  0.07252408,  0.54906091],
#        [ 0.31725455, -0.32409435, -0.47971899,  0.75112056]])

# %%
top2eval = real_eig[0:2]
top2eval
# Out:
# array([[ 0.36158968, -0.08226889,  0.85657211,  0.35884393],
#        [-0.65653988, -0.72971237,  0.1757674 ,  0.07470647]])

# %%
Final_data = np.dot(original_data.T,top2eval.T)

# %%
Data = pd.DataFrame(Final_data,columns=['PC1','PC2'])
Data['Species'] = df['Species']

# %%
Data
# Out:
#           PC1       PC2         Species
# 0    2.827136 -5.641331     Iris-setosa
# 1    2.795952 -5.145167     Iris-setosa
# 2    2.621524 -5.177378     Iris-setosa
# 3    2.764906 -5.003599     Iris-setosa
# 4    2.782750 -5.648648     Iris-setosa
# ..        ...       ...             ...
# 145  7.455360 -5.502139  Iris-virginica
# 146  7.037007 -4.939703  Iris-virginica
# 147  7.275389 -5.393243  Iris-virginica
# 148  7.412972 -5.430600  Iris-virginica
# 149  6.901009 -5.031837  Iris-virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# ## Plot

# %%
soa = np.array([[0, 0, eigen_vals[0] * top2eval[0][0], eigen_vals[0] * top2eval[0][1]]])
soa1 = np.array([[0, 0, eigen_vals[1] * top2eval[1][0], eigen_vals[1] * top2eval[1][1]]])
x0, y0, u0, v0 = zip(*soa)
x1, y1, u1, v1 = zip(*soa1)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
DataScaled = sc.fit_transform(Data.iloc[:,:2])
DataScaled = pd.DataFrame(DataScaled,columns=["PC1","PC2"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.scatter(DataScaled["PC1"],DataScaled["PC2"],color="limegreen",edgecolors='black',label='Reduced Dim data points')
plt.title('Plot of 2D Standardized synthetic data and eigen directions',fontsize=15)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.quiver(0,0, eigen_vals[0] * top2eval[0][0], eigen_vals[0] * top2eval[0][1], angles='xy', scale_units='xy',color='red', scale=0.5, width=0.005)
plt.quiver(0,0, eigen_vals[1] * top2eval[1][0], eigen_vals[1] * top2eval[1][1], angles='xy', scale_units='xy',color='red', scale=0.5, width=0.005, label='Eigen Vectors')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Reconstruction

# %%
X_new = Data.iloc[:,:2]
Q = top2eval
X_new = np.dot(X_new,Q)

# %%
X_new = pd.DataFrame(X_new,columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
X_new['Species'] = df['Species']
X_new
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0         4.726022      3.883964       1.430084      0.593057     Iris-setosa
# 1         4.388995      3.524472       1.490582      0.618933     Iris-setosa
# 2         4.347071      3.562327       1.335510      0.553934     Iris-setosa
# 3         4.284824      3.423723       1.488872      0.618368     Iris-setosa
# 4         4.714777      3.892955       1.390778      0.576582     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145       6.308155      3.401635       5.418957      2.264265  Iris-virginica
# 146       5.787621      3.025636       5.159465      2.156159  Iris-virginica
# 147       6.171585      3.336978       5.283939      2.207819  Iris-virginica
# 148       6.245860      3.352919       5.395223      2.254399  Iris-virginica
# 149       5.798935      3.104055       5.026779      2.100474  Iris-virginica
#
# [150 rows x 5 columns]

# %%
def RMSE():
    for i in range(4):
        error = np.array(df.iloc[:,i]) - np.array(X_new.iloc[:,i])
        error_sq = np.square(error)
        sum_error_sq = pow((np.sum(error_sq)/len(df)) , 0.5)
        print(f"RMSE for {df.columns[i]} = {sum_error_sq}")

RMSE()
# Out:
# RMSE for SepalLengthCm = 0.39891646671900133
# RMSE for SepalWidthCm = 0.409530408111965
# RMSE for PetalLengthCm = 0.08130437898001235
# RMSE for PetalWidthCm = 0.42744813492645645

# %% [markdown]
# # KNN

# %%
data = Data.copy(deep=True)
data
# Out:
#           PC1       PC2         Species
# 0    2.827136 -5.641331     Iris-setosa
# 1    2.795952 -5.145167     Iris-setosa
# 2    2.621524 -5.177378     Iris-setosa
# 3    2.764906 -5.003599     Iris-setosa
# 4    2.782750 -5.648648     Iris-setosa
# ..        ...       ...             ...
# 145  7.455360 -5.502139  Iris-virginica
# 146  7.037007 -4.939703  Iris-virginica
# 147  7.275389 -5.393243  Iris-virginica
# 148  7.412972 -5.430600  Iris-virginica
# 149  6.901009 -5.031837  Iris-virginica
#
# [150 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(data.iloc[:,:2],data.iloc[:,-1],test_size=0.3,random_state=104,shuffle=True)

# %%
def Euclidean_Distance(A,B):
    return pow(pow(A-B,2).sum(),0.5)

# %%
d_xtest = []

for i in range(len(xtest)):
    temp = []
    for j in range(len(xtrain)):
        temp.append([Euclidean_Distance(np.array(xtrain.iloc[j]),np.array(xtest.iloc[i])),ytrain.iloc[j]])
    temp.sort(key = lambda temp: temp[0])
    d_xtest.append(temp[:5])

d_xtest = np.array(d_xtest)
print(f"Shape Train: {xtrain.shape}, Test Shape: {xtest.shape}, Final Distances: {d_xtest.shape}")
d_xtest
# Out:
# Shape Train: (105, 2), Test Shape: (45, 2), Final Distances: (45, 5, 2)
# array([[['0.15837487298933411', 'Iris-setosa'],
#         ['0.20471614835191562', 'Iris-setosa'],
#         ['0.21418817706712112', 'Iris-setosa'],
#         ['0.22220961017457191', 'Iris-setosa'],
#         ['0.25008343936698957', 'Iris-setosa']],
#
#        [['0.45154587071906616', 'Iris-setosa'],
#         ['0.45245644894566145', 'Iris-setosa'],
#         ['0.455205170990086', 'Iris-setosa'],
#         ['0.5008469291940101', 'Iris-setosa'],
#         ['0.5057964293737672', 'Iris-setosa']],
#
#        [['0.07495276600191622', 'Iris-setosa'],
#         ['0.12699313535734832', 'Iris-setosa'],
#         ['0.15431742749962168', 'Iris-setosa'],
#         ['0.21943564339557545', 'Iris-setosa'],
#         ['0.28282258861281745', 'Iris-setosa']],
#
#        [['0.17429523650940196', 'Iris-versicolor'],
#         ['0.31559447113124695', 'Iris-versicolor'],
#         ['0.3952935767217043', 'Iris-versicolor'],
#         ['0.4171679871179605', 'Iris-versicolor'],
#         ['0.4260151170715957', 'Iris-versicolor']],
#
#        [['0.19802228386547097', 'Iris-virginica'],
#         ['0.2837113352696857', 'Iris-virginica'],
#         ['0.2862118256111529', 'Iris-virginica'],
#         ['0.3728756979547781', 'Iris-virginica'],
#         ['0.3728756979547781', 'Iris-virginica']],
#
#        [['0.26356336533256697', 'Iris-virginica'],
#         ['0.3265863212223672', 'Iris-versicolor'],
#         ['0.35987966055183945', 'Iris-versicolor'],
#         ['0.3600959670052745', 'Iris-versicolor'],
#         ['0.40110944725878167', 'Iris-versicolor']],
#
#        [['0.1597007599999505', 'Iris-versicolor'],
#         ['0.16223667438732098', 'Iris-versicolor'],
#         ['0.22478416770232454', 'Iris-versicolor'],
#         ['0.22521996263969082', 'Iris-versicolor'],
#         ['0.25342965553534', 'Iris-virginica']],
#
#        [['0.14256474940038621', 'Iris-virginica'],
#         ['0.1440761872588189', 'Iris-virginica'],
#         ['0.1463553924688002', 'Iris-virginica'],
#         ['0.1890187749813467', 'Iris-virginica'],
#         ['0.19278274694601016', 'Iris-virginica']],
#
#        [['0.1468670575876073', 'Iris-versicolor'],
#         ['0.1560238383404723', 'Iris-versicolor'],
#         ['0.1641098984735046', 'Iris-versicolor'],
#         ['0.17943026133530102', 'Iris-versicolor'],
#         ['0.23596784170151364', 'Iris-versicolor']],
#
#        [['0.16583661414127937', 'Iris-setosa'],
#         ['0.16741483153830136', 'Iris-setosa'],
#         ['0.21671684880568098', 'Iris-setosa'],
#         ['0.25989010176174376', 'Iris-setosa'],
#         ['0.26668808633967467', 'Iris-setosa']],
#
#        [['0.0', 'Iris-setosa'],
#         ['0.0', 'Iris-setosa'],
#         ['0.0753531055419688', 'Iris-setosa'],
#         ['0.09291742828183523', 'Iris-setosa'],
#         ['0.14185602561207078', 'Iris-setosa']],
#
#        [['0.06605869143903964', 'Iris-versicolor'],
#         ['0.09599136412119846', 'Iris-versicolor'],
#         ['0.10232223816224745', 'Iris-versicolor'],
#         ['0.11902702016414006', 'Iris-versicolor'],
#         ['0.13650818210294427', 'Iris-versicolor']],
#
#        [['0.14141129430640964', 'Iris-versicolor'],
#         ['0.16324793261686638', 'Iris-versicolor'],
#         ['0.17540966875554467', 'Iris-versicolor'],
#         ['0.36354705639786655', 'Iris-versicolor'],
#         ['0.40369973206069704', 'Iris-versicolor']],
#
#        [['0.3633623649246767', 'Iris-virginica'],
#         ['0.3917544137621267', 'Iris-virginica'],
#         ['0.47955928378446383', 'Iris-virginica'],
#         ['0.4807798255959282', 'Iris-virginica'],
#         ['0.5743279038089536', 'Iris-virginica']],
#
#        [['0.17827347425830775', 'Iris-versicolor'],
#         ['0.2103519627047349', 'Iris-versicolor'],
#         ['0.3072816857486688', 'Iris-versicolor'],
#         ['0.32463309319353645', 'Iris-versicolor'],
#         ['0.3405558780487275', 'Iris-versicolor']],
#
#        [['0.07312515084022807', 'Iris-setosa'],
#         ['0.07330757671217072', 'Iris-setosa'],
#         ['0.07504223981779308', 'Iris-setosa'],
#         ['0.098112471005218', 'Iris-setosa'],
#         ['0.1422749963598375', 'Iris-setosa']],
#
#        [['0.2549272254487264', 'Iris-versicolor'],
#         ['0.41807228948017616', 'Iris-versicolor'],
#         ['0.4431892004893839', 'Iris-versicolor'],
#         ['0.4990737812367854', 'Iris-versicolor'],
#         ['0.5164269332618797', 'Iris-versicolor']],
#
#        [['0.19729040686265528', 'Iris-versicolor'],
#         ['0.2518819968664318', 'Iris-versicolor'],
#         ['0.2619206220327517', 'Iris-versicolor'],
#         ['0.2989795903239387', 'Iris-versicolor'],
#         ['0.36514017710837415', 'Iris-versicolor']],
#
#        [['0.13657958704961876', 'Iris-virginica'],
#         ['0.4945998654446362', 'Iris-virginica'],
#         ['0.504035862792869', 'Iris-virginica'],
#         ['0.582640685889368', 'Iris-virginica'],
#         ['0.6311013776471363', 'Iris-virginica']],
#
#        [['0.2231718767250728', 'Iris-setosa'],
#         ['0.2529239866958286', 'Iris-setosa'],
#         ['0.29899003487891546', 'Iris-setosa'],
#         ['0.3027514607120296', 'Iris-setosa'],
#         ['0.3044992882011883', 'Iris-setosa']],
#
#        [['0.09174258493533215', 'Iris-versicolor'],
#         ['0.09520506797621267', 'Iris-versicolor'],
#         ['0.14635539246880083', 'Iris-versicolor'],
#         ['0.1834700090853001', 'Iris-versicolor'],
#         ['0.21251201727363608', 'Iris-versicolor']],
#
#        [['0.05078844873107956', 'Iris-setosa'],
#         ['0.07608543169909726', 'Iris-setosa'],
#         ['0.13031744071838558', 'Iris-setosa'],
#         ['0.13793398374331983', 'Iris-setosa'],
#         ['0.21671464116082842', 'Iris-setosa']],
#
#        [['0.3763905448432908', 'Iris-virginica'],
#         ['0.41487888571351467', 'Iris-virginica'],
#         ['0.42822832964992485', 'Iris-virginica'],
#         ['0.5321905812195717', 'Iris-virginica'],
#         ['0.6347909207417554', 'Iris-virginica']],
#
#        [['0.13657958704961803', 'Iris-setosa'],
#         ['0.14666023653933147', 'Iris-setosa'],
#         ['0.16905440430949525', 'Iris-setosa'],
#         ['0.31899420594629424', 'Iris-setosa'],
#         ['0.3211933000369699', 'Iris-setosa']],
#
#        [['0.08471724915729556', 'Iris-virginica'],
#         ['0.14654058946411802', 'Iris-virginica'],
#         ['0.16860943737287054', 'Iris-virginica'],
#         ['0.26594692226710165', 'Iris-virginica'],
#         ['0.28693791208621394', 'Iris-virginica']],
#
#        [['0.14661910225671784', 'Iris-versicolor'],
#         ['0.2863327224824805', 'Iris-versicolor'],
#         ['0.2919264125896175', 'Iris-versicolor'],
#         ['0.29757028741080493', 'Iris-versicolor'],
#         ['0.3303945880478292', 'Iris-versicolor']],
#
#        [['0.3084485958732221', 'Iris-setosa'],
#         ['0.37300093058360306', 'Iris-setosa'],
#         ['0.3747599634792599', 'Iris-setosa'],
#         ['0.38235349755872117', 'Iris-setosa'],
#         ['0.4679795464775884', 'Iris-setosa']],
#
#        [['0.04498495756898004', 'Iris-setosa'],
#         ['0.09945171655899812', 'Iris-setosa'],
#         ['0.12456698592194533', 'Iris-setosa'],
#         ['0.12456698592194533', 'Iris-setosa'],
#         ['0.12994505088087155', 'Iris-setosa']],
#
#        [['0.03665378835608545', 'Iris-setosa'],
#         ['0.0449849575689799', 'Iris-setosa'],
#         ['0.04498495756898004', 'Iris-setosa'],
#         ['0.10232223816224782', 'Iris-setosa'],
#         ['0.13096031101637656', 'Iris-setosa']],
#
#        [['0.10335169214420124', 'Iris-versicolor'],
#         ['0.14990553200383092', 'Iris-versicolor'],
#         ['0.25486496981722245', 'Iris-versicolor'],
#         ['0.32784123789076897', 'Iris-versicolor'],
#         ['0.33853520150267413', 'Iris-versicolor']],
#
#        [['0.06809705824098689', 'Iris-setosa'],
#         ['0.09174258493533151', 'Iris-setosa'],
#         ['0.14625030168045436', 'Iris-setosa'],
#         ['0.15462044022478935', 'Iris-setosa'],
#         ['0.1601844968741364', 'Iris-setosa']],
#
#        [['0.3638277643536024', 'Iris-setosa'],
#         ['0.4708130988292506', 'Iris-setosa'],
#         ['0.5689153995957074', 'Iris-setosa'],
#         ['0.6161269059147731', 'Iris-setosa'],
#         ['0.630674282004431', 'Iris-setosa']],
#
#        [['0.04876063891185594', 'Iris-virginica'],
#         ['0.21313273435890165', 'Iris-virginica'],
#         ['0.21313273435890165', 'Iris-virginica'],
#         ['0.22504760139793986', 'Iris-virginica'],
#         ['0.337851908470474', 'Iris-virginica']],
#
#        [['0.3155681167281427', 'Iris-setosa'],
#         ['0.3600400170933082', 'Iris-setosa'],
#         ['0.3634203417139005', 'Iris-setosa'],
#         ['0.3864215641500932', 'Iris-setosa'],
#         ['0.4007797219748178', 'Iris-setosa']],
#
#        [['0.09486555254446455', 'Iris-virginica'],
#         ['0.16216909719211184', 'Iris-virginica'],
#         ['0.17074704392186557', 'Iris-virginica'],
#         ['0.24606438038527034', 'Iris-virginica'],
#         ['0.25873722767930635', 'Iris-virginica']],
#
#        [['0.06809705824098689', 'Iris-versicolor'],
#         ['0.14990553200383092', 'Iris-versicolor'],
#         ['0.243581899476656', 'Iris-versicolor'],
#         ['0.31118056149648793', 'Iris-versicolor'],
#         ['0.33959760518139576', 'Iris-versicolor']],
#
#        [['0.17862858616575528', 'Iris-versicolor'],
#         ['0.20834783127537315', 'Iris-versicolor'],
#         ['0.21688216348903364', 'Iris-versicolor'],
#         ['0.25213512215770706', 'Iris-versicolor'],
#         ['0.29995720244650115', 'Iris-versicolor']],
#
#        [['0.053370305038553674', 'Iris-setosa'],
#         ['0.13043450604523238', 'Iris-setosa'],
#         ['0.13494689154141556', 'Iris-setosa'],
#         ['0.13982845106768169', 'Iris-setosa'],
#         ['0.19465595513363687', 'Iris-setosa']],
#
#        [['0.07559153180479553', 'Iris-versicolor'],
#         ['0.23905717481668137', 'Iris-versicolor'],
#         ['0.249178363488557', 'Iris-versicolor'],
#         ['0.3014076104791878', 'Iris-versicolor'],
#         ['0.3687047211620431', 'Iris-versicolor']],
#
#        [['0.08833326870422833', 'Iris-setosa'],
#         ['0.13657958704961953', 'Iris-setosa'],
#         ['0.17737816486951646', 'Iris-setosa'],
#         ['0.21813940274204793', 'Iris-setosa'],
#         ['0.21813940274204793', 'Iris-setosa']],
#
#        [['0.14296644248151424', 'Iris-versicolor'],
#         ['0.14911661275652813', 'Iris-versicolor'],
#         ['0.17631823570615818', 'Iris-versicolor'],
#         ['0.35552992079758133', 'Iris-versicolor'],
#         ['0.405537810080725', 'Iris-versicolor']],
#
#        [['0.09520506797621246', 'Iris-setosa'],
#         ['0.14948108647956934', 'Iris-setosa'],
#         ['0.14948108647957026', 'Iris-setosa'],
#         ['0.1503263884886463', 'Iris-setosa'],
#         ['0.16074939099789504', 'Iris-setosa']],
#
#        [['0.09683713251933826', 'Iris-setosa'],
#         ['0.10132032785389443', 'Iris-setosa'],
#         ['0.14141129430640878', 'Iris-setosa'],
#         ['0.1560238383404716', 'Iris-setosa'],
#         ['0.16599777826262496', 'Iris-setosa']],
#
#        [['0.1980257046927993', 'Iris-versicolor'],
#         ['0.22388104952688834', 'Iris-versicolor'],
#         ['0.23467684926109714', 'Iris-versicolor'],
#         ['0.3083491352096526', 'Iris-versicolor'],
#         ['0.32236645495207883', 'Iris-versicolor']],
#
#        [['0.025181719700701714', 'Iris-setosa'],
#         ['0.21130694557883503', 'Iris-setosa'],
#         ['0.24517289143292925', 'Iris-setosa'],
#         ['0.2830711329396045', 'Iris-setosa'],
#         ['0.29968806809649146', 'Iris-setosa']]], dtype='<U32')

# %%
import statistics as stat
predicted= np.array([stat.mode(d_xtest[i][:,1]) for i in range(len(d_xtest))])

# %%
Final = np.array([predicted,ytest]).T
Final_DF = pd.DataFrame(Final,columns=['Predicted','Actual'])
Final_DF
# Out:
#           Predicted           Actual
# 0       Iris-setosa      Iris-setosa
# 1       Iris-setosa      Iris-setosa
# 2       Iris-setosa      Iris-setosa
# 3   Iris-versicolor  Iris-versicolor
# 4    Iris-virginica   Iris-virginica
# 5   Iris-versicolor  Iris-versicolor
# 6   Iris-versicolor  Iris-versicolor
# 7    Iris-virginica   Iris-virginica
# 8   Iris-versicolor  Iris-versicolor
# 9       Iris-setosa      Iris-setosa
# 10      Iris-setosa      Iris-setosa
# 11  Iris-versicolor  Iris-versicolor
# 12  Iris-versicolor  Iris-versicolor
# 13   Iris-virginica   Iris-virginica
# 14  Iris-versicolor  Iris-versicolor
# 15      Iris-setosa      Iris-setosa
# 16  Iris-versicolor  Iris-versicolor
# 17  Iris-versicolor  Iris-versicolor
# 18   Iris-virginica   Iris-virginica
# 19      Iris-setosa      Iris-setosa
# 20  Iris-versicolor  Iris-versicolor
# 21      Iris-setosa      Iris-setosa
# 22   Iris-virginica   Iris-virginica
# 23      Iris-setosa      Iris-setosa
# 24   Iris-virginica   Iris-virginica
# 25  Iris-versicolor  Iris-versicolor
# 26      Iris-setosa      Iris-setosa
# 27      Iris-setosa      Iris-setosa
# 28      Iris-setosa      Iris-setosa
# 29  Iris-versicolor  Iris-versicolor
# 30      Iris-setosa      Iris-setosa
# 31      Iris-setosa      Iris-setosa
# 32   Iris-virginica   Iris-virginica
# 33      Iris-setosa      Iris-setosa
# 34   Iris-virginica   Iris-virginica
# 35  Iris-versicolor  Iris-versicolor
# 36  Iris-versicolor  Iris-versicolor
# 37      Iris-setosa      Iris-setosa
# 38  Iris-versicolor  Iris-versicolor
# 39      Iris-setosa      Iris-setosa
# 40  Iris-versicolor  Iris-versicolor
# 41      Iris-setosa      Iris-setosa
# 42      Iris-setosa      Iris-setosa
# 43  Iris-versicolor  Iris-versicolor
# 44      Iris-setosa      Iris-setosa

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
CM = confusion_matrix(ytest,predicted)
CM
# Out:
# array([[20,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  0,  8]])

# %%
ConfusionMatrixDisplay(CM).plot()
